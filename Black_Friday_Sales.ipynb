# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install numpy --upgrade

# %%
# import os
df = pd.read_csv(r'C:\Users\sai\Data Science\data\train.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.rename(columns={'Product_Category_1': 'Product1','Product_Category_2':'Product2','Product_Category_3':'Product3','Stay_In_Current_City_Years':'stay_city'},inplace=True)
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category stay_city  \
# 0  1000001  P00069042      F   0-17          10             A         2
# 1  1000001  P00248942      F   0-17          10             A         2
# 2  1000001  P00087842      F   0-17          10             A         2
# 3  1000001  P00085442      F   0-17          10             A         2
# 4  1000002  P00285442      M    55+          16             C        4+
# 5  1000003  P00193542      M  26-35          15             A         3
# 6  1000004  P00184942      M  46-50           7             B         2
# 7  1000004  P00346142      M  46-50           7             B         2
# 8  1000004   P0097242      M  46-50           7             B         2
# 9  1000005  P00274942      M  26-35          20             A         1
#
#    Marital_Status  Product1  Product2  Product3  Purchase
# 0               0         3       NaN       NaN      8370
# 1               0         1       6.0      14.0     15200
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'stay_city', 'Marital_Status', 'Product1', 'Product2', 'Product3',
#        'Purchase'],
#       dtype='object')

# %%
df['Purchase'].nunique()
# Out:
# 18105

# %%
df['stay_city']=df['stay_city'].str.replace('+','')
df['stay_city']
df.head(10)
# Out:
# C:\Users\sai\AppData\Local\Temp\ipykernel_14320\2257546517.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['stay_city']=df['stay_city'].str.replace('+','')
#    User_ID Product_ID Gender    Age  Occupation City_Category stay_city  \
# 0  1000001  P00069042      F   0-17          10             A         2
# 1  1000001  P00248942      F   0-17          10             A         2
# 2  1000001  P00087842      F   0-17          10             A         2
# 3  1000001  P00085442      F   0-17          10             A         2
# 4  1000002  P00285442      M    55+          16             C         4
# 5  1000003  P00193542      M  26-35          15             A         3
# 6  1000004  P00184942      M  46-50           7             B         2
# 7  1000004  P00346142      M  46-50           7             B         2
# ...

# %%
df['Age'].unique
# Out:
# <bound method Series.unique of 0          0-17
# 1          0-17
# 2          0-17
# 3          0-17
# 4           55+
#           ...
# 550063    51-55
# 550064    26-35
# 550065    26-35
# 550066      55+
# 550067    46-50
# Name: Age, Length: 550068, dtype: object>

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})
df.head(10)
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category stay_city  \
# 0  1000001  P00069042      F    1          10             A         2
# 1  1000001  P00248942      F    1          10             A         2
# 2  1000001  P00087842      F    1          10             A         2
# 3  1000001  P00085442      F    1          10             A         2
# 4  1000002  P00285442      M    7          16             C         4
# 5  1000003  P00193542      M    3          15             A         3
# 6  1000004  P00184942      M    5           7             B         2
# 7  1000004  P00346142      M    5           7             B         2
# 8  1000004   P0097242      M    5           7             B         2
# 9  1000005  P00274942      M    3          20             A         1
#
#    Marital_Status  Product1  Product2  Product3  Purchase
# 0               0         3       NaN       NaN      8370
# 1               0         1       6.0      14.0     15200
# ...

# %%
gender_map={'F':0,'M':1}
df['Gender']=df['Gender'].replace(gender_map)
df.head(10)
# Out:
#    User_ID Product_ID  Gender  Age  Occupation City_Category stay_city  \
# 0  1000001  P00069042       0    1          10             A         2
# 1  1000001  P00248942       0    1          10             A         2
# 2  1000001  P00087842       0    1          10             A         2
# 3  1000001  P00085442       0    1          10             A         2
# 4  1000002  P00285442       1    7          16             C         4
# 5  1000003  P00193542       1    3          15             A         3
# 6  1000004  P00184942       1    5           7             B         2
# 7  1000004  P00346142       1    5           7             B         2
# 8  1000004   P0097242       1    5           7             B         2
# 9  1000005  P00274942       1    3          20             A         1
#
#    Marital_Status  Product1  Product2  Product3  Purchase
# 0               0         3       NaN       NaN      8370
# 1               0         1       6.0      14.0     15200
# ...

# %%
df['stay_city'] = df['stay_city'].str.replace('+','')
df['stay_city'] = df['stay_city'].astype(int)
# converted to int
df.head(10)
# Out:
# C:\Users\sai\AppData\Local\Temp\ipykernel_14320\1179582124.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['stay_city'] = df['stay_city'].str.replace('+','')
#    User_ID Product_ID  Gender  Age  Occupation City_Category  stay_city  \
# 0  1000001  P00069042       0    1          10             A          2
# 1  1000001  P00248942       0    1          10             A          2
# 2  1000001  P00087842       0    1          10             A          2
# 3  1000001  P00085442       0    1          10             A          2
# 4  1000002  P00285442       1    7          16             C          4
# 5  1000003  P00193542       1    3          15             A          3
# 6  1000004  P00184942       1    5           7             B          2
# 7  1000004  P00346142       1    5           7             B          2
# ...

# %%
df['Product2'] = df['Product2'].fillna(0)
df
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  stay_city  \
# 0       1000001  P00069042       0    1          10             A          2
# 1       1000001  P00248942       0    1          10             A          2
# 2       1000001  P00087842       0    1          10             A          2
# 3       1000001  P00085442       0    1          10             A          2
# 4       1000002  P00285442       1    7          16             C          4
# ...         ...        ...     ...  ...         ...           ...        ...
# 550063  1006033  P00372445       1    6          13             B          1
# 550064  1006035  P00375436       0    3           1             C          3
# 550065  1006036  P00375436       0    3          15             B          4
# 550066  1006038  P00375436       0    7           1             C          2
# 550067  1006039  P00371644       0    5           0             B          4
#
# ...

# %%
df['Product3'] = df['Product3'].fillna(0)
df
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City_Category  stay_city  \
# 0       1000001  P00069042       0    1          10             A          2
# 1       1000001  P00248942       0    1          10             A          2
# 2       1000001  P00087842       0    1          10             A          2
# 3       1000001  P00085442       0    1          10             A          2
# 4       1000002  P00285442       1    7          16             C          4
# ...         ...        ...     ...  ...         ...           ...        ...
# 550063  1006033  P00372445       1    6          13             B          1
# 550064  1006035  P00375436       0    3           1             C          3
# 550065  1006036  P00375436       0    3          15             B          4
# 550066  1006038  P00375436       0    7           1             C          2
# 550067  1006039  P00371644       0    5           0             B          4
#
# ...

# %%
df.isnull().sum()
# Out:
# User_ID           0
# Product_ID        0
# Gender            0
# Age               0
# Occupation        0
# City_Category     0
# stay_city         0
# Marital_Status    0
# Product1          0
# Product2          0
# Product3          0
# Purchase          0
# dtype: int64

# %%
df=df.drop(['User_ID','Product_ID'],axis=1)
df
# Out:
#         Gender  Age  Occupation City_Category  stay_city  Marital_Status  \
# 0            0    1          10             A          2               0
# 1            0    1          10             A          2               0
# 2            0    1          10             A          2               0
# 3            0    1          10             A          2               0
# 4            1    7          16             C          4               0
# ...        ...  ...         ...           ...        ...             ...
# 550063       1    6          13             B          1               1
# 550064       0    3           1             C          3               0
# 550065       0    3          15             B          4               1
# 550066       0    7           1             C          2               0
# 550067       0    5           0             B          4               1
#
#         Product1  Product2  Product3  Purchase
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category', 'stay_city',
#        'Marital_Status', 'Product1', 'Product2', 'Product3', 'Purchase'],
#       dtype='object')

# %%
df
# Out:
#         Gender  Age  Occupation City_Category  stay_city  Marital_Status  \
# 0            0    1          10             A          2               0
# 1            0    1          10             A          2               0
# 2            0    1          10             A          2               0
# 3            0    1          10             A          2               0
# 4            1    7          16             C          4               0
# ...        ...  ...         ...           ...        ...             ...
# 550063       1    6          13             B          1               1
# 550064       0    3           1             C          3               0
# 550065       0    3          15             B          4               1
# 550066       0    7           1             C          2               0
# 550067       0    5           0             B          4               1
#
#         Product1  Product2  Product3  Purchase
# ...

# %%
# Visualizing the Individual columns
plt.figure(figsize=(8,5))
sns.countplot(x='Gender',data=df.head(10))
plt.title('Countplot for Gender')
# Out:
# Text(0.5, 1.0, 'Countplot for Gender')

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Age' ,data=df.head(10))
plt.title('Countplot for Age')
# Out:
# Text(0.5, 1.0, 'Countplot for Age')

# %%
# plt.subplot(5,2,2)
sns.kdeplot(x='Age',data=df)
plt.title('KDEPLOT  for AGE')
# Out:
# Text(0.5, 1.0, 'KDEPLOT  for AGE')

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Occupation' ,data=df.head(10))
plt.title('Countplot for Occupation')
# Out:
# Text(0.5, 1.0, 'Countplot for Occupation')

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='City_Category' ,data=df.head(10))
plt.title('Countplot for City_Category')
# Out:
# Text(0.5, 1.0, 'Countplot for City_Category')

# %%
# visualizing Individual columns
# plt.subplot(nrows, ncols, plot_number)
plt.figure(figsize=(20,18))

plt.subplot(5,2,1)
sns.countplot(x='Gender',data=df.head(10))
plt.title('Countplot for Gender')

plt.subplot(5,2,2)
sns.kdeplot(x='Age',data=df)
plt.title('KDEPLOT  for AGE')

plt.subplot(5,2,3)
sns.countplot(x='Occupation',data=df)
plt.title('COUNTPLOT for Occupation')

plt.subplot(5,2,4)
sns.countplot(x='City_Category',data=df)
plt.title('COUNTPLOT for City_Category')

plt.subplot(5,2,5)
sns.countplot(x='stay_city',data=df)
plt.title('COUNTPLOT for stay_city')

plt.subplot(5,2,6)
sns.countplot(x='Marital_Status',data=df)
plt.title('COUNTPLOT for Marital_Status')

plt.subplot(5,2,7)
sns.countplot(x='Product1',data=df)
plt.title('COUNTPLOT for Product1 ')

plt.subplot(5,2,8)
sns.countplot(x='Product2',data=df)
plt.title('COUNTPLOT for Product2 ')

plt.subplot(5,2,9)
sns.countplot(x='Product3',data=df)
plt.title('COUNTPLOT for Product3 ')

plt.subplot(5,2,10)
sns.kdeplot(x='Purchase',data=df)
plt.title('COUNTPLOT for Purchase ')
# Out:
# Text(0.5, 1.0, 'COUNTPLOT for Purchase ')

# %%
df1=df.groupby('Age')['Purchase'].mean().sort_values(ascending= False)
df1
plt.figure(figsize=(8,4))
sns.barplot(x=df1.index , y= df1.values)
plt.title("Age Vs Purchased Barplot")
plt.show()

# %%
df2=df.groupby('Occupation')['Purchase'].mean().sort_values(ascending =False)
df2
plt.figure(figsize=(12,4))
sns.barplot(x=df2.index , y=df2.values)
plt.title('Occupation Vs Purchased Barplot')
plt.show()

# %%
df3=df.groupby('Product1')['Purchase'].mean().sort_values(ascending =False)
df3
plt.figure(figsize=(12,4))
sns.barplot(x=df2.index , y=df2.values)
plt.title('Product1 Vs Purchased Barplot')
plt.show()

# %%
sns.barplot(x='Product1' , y='Purchase' , data=df)
# Out:
# <AxesSubplot:xlabel='Product1', ylabel='Purchase'>

# %%
sns.barplot(x='Product2', y='Purchase' , data=df)
# Out:
# <AxesSubplot:xlabel='Product2', ylabel='Purchase'>

# %%
sns.barplot(x='Product3' , y='Purchase', data=df)
# Out:
# <AxesSubplot:xlabel='Product3', ylabel='Purchase'>

# %%
df.groupby(['City_Category']).sum().plot(kind='pie',y='Purchase')
plt.title('City Category wrt Purchase')
plt.show()

# %%
df.groupby(['stay_city']).sum().plot(kind='pie', y='Purchase')
plt.title('Staying in Current city wrt Purchase')
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category', 'stay_city',
#        'Marital_Status', 'Product1', 'Product2', 'Product3', 'Purchase'],
#       dtype='object')

# %%
df.groupby(['Marital_Status']).sum().plot(kind='pie', y='Purchase')
plt.title('Marital Status wrt Purchase')
plt.show()
